# %% [markdown]
# Attitude and Position Integration: https://www.vectornav.com/resources/inertial-navigation-primer/math-fundamentals/math-coning
#
# ## Position Determination from YPR (Delta Velocity method)

# %%
import pandas as pd
import numpy as np
from math import sin, cos, pi, atan2, asin
import matplotlib.pyplot as plt
from scipy import integrate
import Helper_Functions as hf

#from get_YPR_matrix import convert_YPR_fixed_frame

# %%
################## CONSTANTS ##################
# gravity
g = 9.81  # m/s^2
# m to ft
ft = 3.2884  # ft/m

################## DATA FRAME ##################
datafile = '../Data/Subscale2/Subscale2_Truncated_014355.csv'
fields = ['Timestamp', 'Pres',
  'dTheta X', 'dTheta Y', 'dTheta Z',
  'Roll', 'Pitch', 'Yaw',
  'dVel X', 'dVel Y', 'dVel Z',
  'Qtn[0]', 'Qtn[1]', 'Qtn[2]', 'Qtn[3]',
  'LinearAccelNed X', 'LinearAccelNed Y', 'LinearAccelNed Z'
  ]

df = pd.read_csv(datafile, skipinitialspace=True, usecols=fields)

################## INIT VECTORS ##################
all_time = df['Timestamp'].values

tdata = all_time
tdata = tdata - all_time[0]
L = tdata.shape[0]

# %%
ax_vn = df['LinearAccelNed X'] * ft
ay_vn = df['LinearAccelNed Y'] * ft
az_vn = df['LinearAccelNed Z'] * -ft

accel_xyz = [ax_vn, ay_vn, az_vn]
v_vec, x_vec = hf.numerical_int(accel_xyz, tdata)

vx_vn, vy_vn, vz_vn = v_vec[0], v_vec[1], v_vec[2]
x_vn, y_vn, z_vn = x_vec[0], x_vec[1], x_vec[2]

# %%
fig1 = plt.figure(1, figsize=(8,8))
ax = plt.subplot(111)
l2 = ax.plot(tdata, ax_vn, color='red', label='x')
l3 = ax.plot(tdata, ay_vn, color='green', label='y')
l4 = ax.plot(tdata, az_vn, color='purple', label='z')
l5 = plt.axhline(y=0, color='black', linewidth=2)
ax.set_title("LinAccelNed From VN")
ax.set_xlabel('Time (s)')
ax.set_ylabel("Acceleration [ft/s2]")
ax.legend()
plt.show()

# %%
fig1 = plt.figure(1, figsize=(8,8))
ax = plt.subplot(111)
l2 = ax.plot(tdata, vx_vn, color='red', label='x')
l3 = ax.plot(tdata, vy_vn, color='green', label='y')
l4 = ax.plot(tdata, vz_vn, color='purple', label='z')
l5 = plt.axhline(y=0, color='black', linewidth=2)
ax.set_title("Velocity Integrated From VN")
ax.set_xlabel('Time (s)')
ax.set_ylabel("Velocity [ft/s]")
ax.legend()
plt.show()

# %% [markdown]
# Vanilla numerical integration:
# - We don't expect this to work because the IMU acceleration data is pretty biased.  When sitting on the pad the acceleration is not zero, sometimes over 1 m/s

# %%
P = df['Pres']
v_NASA_pres = np.vectorize(hf.nasa_pres)
altitude_NASA_pres = v_NASA_pres(P, P0=99.035, T0=288.1)*ft
#T0 really was 303.3966... this would've been biased by the RPi tho

# %%
fig1 = plt.figure(1, figsize=(8,8))
# Just the Displacement:
ax = plt.subplot(111)
l1 = ax.plot(tdata, altitude_NASA_pres, color='blue', label='Pressure Derived')
l4 = ax.plot(tdata, z_vn, color='purple', label='Numerical Integration')
l5 = plt.axhline(y=0, color='black', linewidth=2)
ax.set_title("Altitude From Numerical Integration")
ax.set_xlabel('Time (s)')
ax.set_ylabel("Altitude [ft]")
ax.legend()
plt.show()

# %%
fig1 = plt.figure(1, figsize=(8,8))
# Just the Displacement:
ax = plt.subplot(111)
l2 = ax.plot(tdata, x_vn, color='red', label='x')
l3 = ax.plot(tdata, y_vn, color='green', label='y')
l5 = plt.axhline(y=0, color='black', linewidth=2)
ax.set_title("Displacement From Numerical Integration")
ax.set_xlabel('Time (s)')
ax.set_ylabel("Displacement [ft]")
ax.legend()
plt.show()

# %% [markdown]
# I applied a high pass filter, and increasing the magnitude just makes it worse.  This has little effect and is not the solution we are looking for.

# %%
# Grab the original data
ax_vn = df['LinearAccelNed X'] * ft
ay_vn = df['LinearAccelNed Y'] * ft
az_vn = df['LinearAccelNed Z'] * -ft

# Do some filtering
hpf_threshold = 1
hpfx = [val if abs(val) > hpf_threshold else 0 for val in ax_vn]
hpfy = [val if abs(val) > hpf_threshold else 0 for val in ay_vn]
hpfz = [val if abs(val) > hpf_threshold else 0 for val in az_vn]

# Pass in the new data
accel_xyz = [hpfx, hpfy, hpfz]
v_vec, x_vec = hf.numerical_int(accel_xyz, tdata)

# Plot the results
vx_vn, vy_vn, vz_vn = v_vec[0], v_vec[1], v_vec[2]
x_vn, y_vn, z_vn = x_vec[0], x_vec[1], x_vec[2]
fig1 = plt.figure(1, figsize=(8,8))
ax = plt.subplot(111)
l2 = ax.plot(tdata, x_vn, color='red', label='x')
l3 = ax.plot(tdata, y_vn, color='green', label='y')
l4 = ax.plot(tdata, z_vn, color='purple', label='z')
l5 = plt.axhline(y=0, color='black', linewidth=2)
ax.set_title("Altitude From Numerical Integration")
ax.set_xlabel('Time (s)')
ax.set_ylabel("Altitude [ft]")
ax.legend()
plt.show()

# %% [markdown]
# Pulled from the original NB from the Fall.  Did not make any edits, unsuprisingly still does not work

# %%
################## SCIPY INTEGRATE ##################
# integrate.simps(y, x=None, dx=1, axis=-1, even='avg')
# integrate.romb(y, dx=1.0, axis=- 1, show=False)
# zddot = zddot[0:4097]

xddot = df['LinearAccelNed X']
yddot = df['LinearAccelNed Y']
zddot = df['LinearAccelNed Z'] * -1

x, xdot = np.zeros(len(xddot)), np.zeros(len(xddot))
y, ydot = np.zeros(len(yddot)), np.zeros(len(yddot))
z, zdot = np.zeros(len(zddot)), np.zeros(len(zddot))
dt = tdata[1]

zdot = integrate.cumtrapz(zddot, tdata, initial=0)
z = integrate.cumtrapz(zdot, tdata, initial=0)

az0 = 1
zdotA = integrate.cumtrapz(zddot+az0, tdata, initial=0)
zOffset = integrate.cumtrapz(zdotA, tdata, initial=0)

zddotHPF = [val if abs(val) > 2.23 else 0 for val in zddot]
zdotHPF = integrate.cumtrapz(zddotHPF, tdata, initial=0)
zHPF = integrate.cumtrapz(zdotHPF, tdata, initial=0)

apogSciPy = max(z)*ft
apogSciPyOffset = max(zOffset)*ft
apogSciPyHPF = max(zHPF)*ft
apogPD_NASA = max(altitude_NASA_pres)

fig1 = plt.figure(1, figsize=(8,8))
# Just the Displacement:
ax = plt.subplot(111)
l1 = ax.plot(tdata, z*ft, color='blue', label='SciPy.Integrate')
#l2 = ax.plot(tdata, zOffset*ft, color='green', label='SciPy.Integrate (Offset)')
l3 = ax.plot(tdata, altitude_NASA_pres, color='purple', label='Pressure Derived')
l4 = ax.plot(tdata, zHPF*ft, color='green', label='SciPy.Integrate (HPF)')
l5 = plt.axhline(y=0, color='black', linewidth=2)
l_apogSciPy = plt.axhline(y=apogSciPy, color='red', linestyle='--', linewidth=0.5, label="SciPy: %.0f ft" % apogSciPy)
#l_apogSciPyOffset = plt.axhline(y=apogSciPyOffset, color='red', linestyle='--', linewidth=0.5, label="apogSciPyOffset: %.0f ft" % apogSciPyOffset)
l_apogSciPyHPF = plt.axhline(y=apogSciPyHPF, color='red', linestyle='--', linewidth=0.5, label="apogSciPyHPF: %.0f ft" % apogSciPyHPF)
l_apogPD_NASA = plt.axhline(y=apogPD_NASA, color='red', linestyle='--', linewidth=0.5, label="Apogee: %.0f ft" % apogPD_NASA)
ax.set_title("Altitude From Numerical Integration")
ax.set_xlabel('Time (s)')
ax.set_ylabel("Altitude [ft]")
ax.legend()
plt.show()

# %% [markdown]
# ## Using Delta Velocity

# %%
# dVelocity [m/s]
dvx = np.array(df['dVel X'])
dvy = np.array(df['dVel Y'])
dvz = np.array(df['dVel Z'])

dVel = np.dstack((dvx, dvy, dvz))
dVel = np.reshape(dVel, (dVel.shape[2], dVel.shape[1]))
dVel0 = dVel[:,0]
assert dVel0[0]==dvx[0]
print(f"dVel0 = {dVel0}")
# Out:
# dVel0 = [ 0.0644567 -0.101061  -0.0838881]

# %% [markdown]
# Let's visualize the Delta Velocity Measurements

# %%
fig1 = plt.figure(1, figsize=(8,8))
ax = plt.subplot(111)
l2 = ax.plot(tdata, dvx, color='red', label='x')
l3 = ax.plot(tdata, dvy, color='green', label='y')
l4 = ax.plot(tdata, dvz, color='purple', label='z')
l5 = plt.axhline(y=0, color='black', linewidth=2)
ax.set_title("Delta Velocity From VN")
ax.set_xlabel('Time (s)')
ax.set_ylabel("Change in Velocity [m/s]")
ax.legend()
plt.show()

# %% [markdown]
# Note that the Delta Velocity is essentially just the LinearAccelerationNed but just with some of the peaks flipped (wrt sign).
#
# Should be able to get the YPR from the quaternion, which is theoretically not based on the magnetometer
#
# ## Quaternion: Raw From VN

# %%
# Quaternion
# The estimated attitude quaternion: last term is the scalar value
# The attitude is given as the body frame wrt the local North East Down (NED) frame
qx = np.array(df['Qtn[0]'])
qy = np.array(df['Qtn[1]'])
qz = np.array(df['Qtn[2]'])
qw = np.array(df['Qtn[3]'])

quats = np.dstack((qx, qy, qz, qw))
quats = np.reshape(quats, (quats.shape[2], quats.shape[1]))
quat0 = np.reshape(quats[:,0], (4,1))
print(f"quat0 = {quat0}")
# Out:
# quat0 = [[ 0.587833]
#  [ 0.757611]
#  [ 0.707952]
#  [-0.459137]]

# %%
def quat2ypr(quat):
    # Figure out if this returns an answer is rads or deg
    # Presumably rads
    
    # Verify that this is actually xyzw and not wxyz
    q1 = quat[0] #[0]  # x
    q2 = quat[1] #[0]  # y
    q3 = quat[2] #[0]  # z
    q0 = quat[3] #[0]  # w
    
    #http://planning.cs.uiuc.edu/node103.html
    # Select terms from the rotation matrix
    #https://image.slidesharecdn.com/lecture4-110104183354-phpapp02/95/robotics-3d-movements-17-728.jpg?cb=1294166705
    r11 = q0**2 + q1**2 - q2**2 - q3**2
    r12 = 2*q1*q2 - 2*q0*q3
    r13 = 2*q1*q3 + 2*q0*q2
    r32 = 2*q2*q3 + 2*q0*q1
    r33 = q0**2 - q1**2 - q2**2 + q3**2
    
    # Alpha, beta, gamma IN RADIANS
    yaw = np.arctan(r12/r11)
    pitch = np.arctan(-r13/np.sqrt(r32**2 + r33**2))
    roll = np.arctan(r32/r33)
    
    return np.array([yaw, pitch, roll])*180/pi

# %%
# Body frame YPR
qbyaw, qbpitch, qbroll = np.zeros(L), np.zeros(L), np.zeros(L)

# This method would be for extracting the YPR from the VN quat.
# Should give the same results as the chosen method below

for idx, quat in enumerate(quats):
    bypr = quat2ypr(quat)
    qbyaw[idx], qbpitch[idx], qbroll[idx] = bypr[0], bypr[1], bypr[2]
'''
fig1 = plt.figure(1, figsize=(8,8))
ax = plt.subplot(111)
l2 = ax.plot(tdata, qbyaw, color='red', label='Yaw')
l3 = ax.plot(tdata, qbpitch, color='green', label='Pitch')
l4 = ax.plot(tdata, qbroll, color='purple', label='Roll')
l5 = plt.axhline(y=0, color='black', linewidth=2)
ax.set_title("Body YPR From VN QUAT")
ax.set_xlabel('Time (s)')
ax.set_ylabel("Angle [deg]")
ax.legend()
plt.show()
'''
0
# Out:
# 0

# %% [markdown]
# ## Using Raw YPR -- may contain errors
#
# I changed my mind and decided to use the raw yaw, pitch, and roll as measured by the VN.  Note that you get different results when you use this vs deriving them from the quaternion.  These results are slightly better but still not good.

# %%
# Just using the raw values directly from the VN
byaw = df['Yaw'].values
bpitch = df['Pitch'].values
broll = df['Roll'].values

# %%
fig1 = plt.figure(1, figsize=(8,8))
ax = plt.subplot(111)
l2 = ax.plot(tdata, byaw, color='red', label='Yaw')
l3 = ax.plot(tdata, bpitch, color='green', label='Pitch')
l4 = ax.plot(tdata, broll, color='purple', label='Roll')
l5 = plt.axhline(y=0, color='black', linewidth=2)
ax.set_title("Body YPR From VN")
ax.set_xlabel('Time (s)')
ax.set_ylabel("Angle [deg]")
ax.legend()
plt.show()

# %%
def make_rot_matrix(yaw, pitch, roll):
    Ry = np.array([[cos(pi/180*yaw), -sin(pi/180*yaw), 0],
                   [sin(pi/180*yaw), cos(pi/180*yaw), 0],
                   [0, 0, 1]])
    Rp = np.array([[cos(pi/180*pitch), 0, sin(pi/180*pitch)],
                   [0, 1, 0],
                   [-sin(pi/180*pitch), 0, cos(pi/180*pitch)]])
    Rr = np.array([[1, 0, 0],
                   [0, cos(pi/180*roll), -sin(pi/180*roll)],
                   [0, sin(pi/180*roll), cos(pi/180*roll)]]) 
    return np.matmul( np.matmul(Ry, Rp), Rr )

# %%
assert L == len(byaw)
dt = tdata[1]
v = np.zeros((3, L))
p = np.zeros((3, L))
g_vec = np.array([[0], [0], [-9.81]])
#g_vec = np.array([[0], [0], [0]])

for i in range(L):
    # Get the dVel at this instance, e.g. body frame
    bdv = np.reshape(dVel[:,i], (3, 1))
    # Convert body frame dVel to fixed world frame dVel
    R = make_rot_matrix(byaw[i], bpitch[i], broll[i])
    idv = np.matmul(R, bdv)
    
    # Correct for gravity, Coriolis term, and current velocity
    # CORIOLIS FORCE PRIMER
    # https://en.wikipedia.org/wiki/Coriolis_force
    # https://www.youtube.com/watch?v=kCbMKSZZO9w
    # Earth's Angular Rate: https://hypertextbook.com/facts/2002/JasonAtkins.shtml
    we = np.array([[0], [0], [7.27*10**(-5)]]) #rad/s
    #############################################################################
    # Does the Earth's rotation need to be about the 23 deg axis and not just assumed
    # to be on the z axis only?
    #############################################################################
    
    v_current = np.reshape(v[:, i], (3,1))
    p_current = np.reshape(p[:, i], (3,1))
    
    # Cross product of the Earth's angular rate (3x1) and the current velocity
    mcp = np.cross((2*we).reshape((3,)), v[:, i]).reshape((3,1))
    dvgc = dt*(g_vec - mcp)
    # Correct delta velocity
    dvc = idv + dvgc

    # Iterate to define next velocity point
    v_new = v_current + dvc
    # Iterate to define next position
    dp = p_current + dt*v_current + dt*dvc/2
    # We can't set a value at index L (@i==L-1, i+1 reaches L)
    if i==(L-1):
        pass
    else:
        v[0, i+1], v[1, i+1], v[2, i+1] = v_new[0], v_new[1], v_new[2]
        p[0, i+1], p[1, i+1], p[2, i+1] = dp[0], dp[1], dp[2]

# %%
fig1 = plt.figure(1, figsize=(8,8))
ax = plt.subplot(111)
l2 = ax.plot(tdata, v[0,:], color='red', linestyle='--', label='dVel x')
l3 = ax.plot(tdata, v[1,:], color='green', linestyle='--', label='dVel y')
l4 = ax.plot(tdata, v[2,:], color='purple', linestyle='--', label='dVel z')

l2 = ax.plot(tdata, ax_vn, color='red', label='NumInt x')
l3 = ax.plot(tdata, ay_vn, color='green', label='NumInt y')
l4 = ax.plot(tdata, az_vn, color='purple', label='NumInt z')

l5 = plt.axhline(y=0, color='black', linewidth=2)
ax.set_title("Velocity From dVel Method")
ax.set_xlabel('Time (s)')
ax.set_ylabel("Velocity [m/s]")
ax.legend()
plt.show()

# %% [markdown]
# ## Preliminary Position Results

# %%
fig1 = plt.figure(1, figsize=(8,8))
ax = plt.subplot(111)
l1 = ax.plot(tdata, p[0,:], 'r', label='X')
l2 = ax.plot(tdata, p[1,:], 'g', label='Y')
l3 = ax.plot(tdata, p[2,:], 'b', label='Z')
l4 = plt.axhline(y=0, color='black', linewidth=2)
ax.set_title("Position Determination")
ax.set_xlabel('Time (s)')
ax.set_ylabel("Position [m]")
ax.legend()
plt.show()

# %% [markdown]
# ## Results Comparisons for Velocity

# %%
dvx_sum = [sum(dvx[0:list(dvx).index(ele)]) for ele in dvx]
dvy_sum = [sum(dvy[0:list(dvy).index(ele)]) for ele in dvy]
dvz_sum = [sum(dvz[0:list(dvz).index(ele)]) for ele in dvz]

# %%
fig1 = plt.figure(1, figsize=(8,8))
ax = plt.subplot(111)
l1 = ax.plot(tdata, dvx_sum, 'ro', label='Summed dVel From VN')
l2 = ax.plot(tdata, v[0,:], '--r', label='dVel Method')
l3 = ax.plot(tdata, vx_vn, color='red', label='Numerical Integration')
l5 = plt.axhline(y=0, color='black', linewidth=2)
ax.set_title("X Velocity")
ax.set_xlabel('Time (s)')
ax.set_ylabel("Velocity [m/s]")
ax.legend()
plt.show()

# %%
fig1 = plt.figure(1, figsize=(8,8))
ax = plt.subplot(111)
l1 = ax.plot(tdata, dvy_sum, 'go', label='Summed dVel From VN')
l2 = ax.plot(tdata, v[1,:], '--g', label='dVel Method')
l3 = ax.plot(tdata, vy_vn, color='green', label='Numerical Integration')
l5 = plt.axhline(y=0, color='black', linewidth=2)
ax.set_title("Y Velocity")
ax.set_xlabel('Time (s)')
ax.set_ylabel("Velocity [m/s]")
ax.legend()
plt.show()

# %%
fig1 = plt.figure(1, figsize=(8,8))
ax = plt.subplot(111)
l1 = ax.plot(tdata, dvz_sum, 'bo', label='Summed dVel From VN')
l2 = ax.plot(tdata, v[2,:], '--b', label='dVel Method')
l3 = ax.plot(tdata, vz_vn, color='blue', label='Numerical Integration')
l5 = plt.axhline(y=0, color='black', linewidth=2)
ax.set_title("Z Velocity")
ax.set_xlabel('Time (s)')
ax.set_ylabel("Velocity [m/s]")
ax.legend()
plt.show()

# %% [markdown]
# ## Angle Determination

# %%
v_len = len(byaw)

bYPR = np.zeros((3, v_len))
ffyaw = np.zeros(v_len)
ffpitch = np.zeros(v_len)
ffroll = np.zeros(v_len)

for i in range(v_len):
    bYPR[0, i], bYPR[1, i], bYPR[2, i] = byaw[i], bpitch[i], broll[i]
    
    YPR = [byaw[i], bpitch[i], broll[i]]

    # Account for IMU misalignment with launch vehicle frame
    post_YPR = hf.convert_abg(YPR)
    # Convert IMU data from body frame to fixed frame
    ff_output = hf.get_ffYPR_theta(post_YPR)
    
    ffyaw[i], ffpitch[i], ffroll[i] = ff_output[0], ff_output[1], ff_output[2]

ffYPR = np.dstack((ffyaw, ffpitch, ffroll))
ffYPR = np.reshape(ffYPR, (ffYPR.shape[2], ffYPR.shape[1]))

# %%
fig1 = plt.figure(1, figsize=(12,12))
ax = plt.subplot(111)
l2 = ax.plot(tdata, ffyaw, 'r', label='Yaw')
l3 = ax.plot(tdata, ffpitch, 'g', label='Pitch')
l4 = ax.plot(tdata, ffroll, 'b', label='Roll')
l5 = plt.axhline(y=0, color='black', linewidth=2)
ax.set_title("Fixed Frame Angle as a Function of Time")
ax.set_xlabel('Time (s)')
ax.set_ylabel("Angle [deg]")
ax.legend()
plt.show()
